# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([4, 5, 6, 8])  # study hours
y = np.array([55, 60, 75, 92])  # marks

_ = plt.scatter(x, y)
_ = plt.plot(x, x * 10 + 2, color='r')  # pred 1 (y = x*10 + 2)
_ = plt.plot(x, x * 10 + 10, color='g')  # pred 2 (y = x*10 + 10)
