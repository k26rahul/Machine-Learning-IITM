# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def plot_xn(x_n, n):
  plt.scatter(*x_n.T, c=n)
  plt.plot(*x_n.T, linewidth=0.2)
  plt.xlabel('x')
  plt.ylabel('y')
  plt.colorbar(label='n')

# %% [markdown]
# **Exponential convergence to point**
#      $x_n = \left(1 + \frac{4}{2^n},\ 3 - \frac{4}{2^n} \right)$

# %%
n = np.arange(1, 11)
x_n = np.column_stack((1 + 4 / 2**n, 3 - 4 / 2**n))
plot_xn(x_n, n)

# %% [markdown]
# **Unit circle jumps (4 points)**
#      $x_n = \left(\cos\left(\frac{\pi}{2}n\right),\ \sin\left(\frac{\pi}{2}n\right)\right)$

# %%
n = np.arange(1, 5)
x_n = np.column_stack((np.cos(np.pi/2 * n), np.sin(np.pi/2 * n)))
plot_xn(x_n, n)

# %% [markdown]
# **Shrinking spiral (4 points)**
#      $x_n = \left(\frac{1}{2^n} \cos\left(\frac{\pi}{2}n\right),\ \frac{1}{2^n} \sin\left(\frac{\pi}{2}n\right)\right)$

# %%
n = np.arange(1, 11)
r = 1 / 2**n
x_n = np.column_stack((r * np.cos(np.pi/2 * n), r * np.sin(np.pi/2 * n)))
plot_xn(x_n, n)

# %% [markdown]
# You scaled only `cos` with `r`, not `sin`.
#
# * **x-component** shrinks with $\frac{1}{2^n}$
# * **y-component** stays on unit circle (not shrinking)
#
# So points lie on an **ellipse**, not a spiral or circle.

# %%
n = np.arange(1, 21)
r = 1 / 2**n
x_n = np.column_stack((r * np.cos(np.pi/2 * n), np.sin(np.pi/2 * n)))
plot_xn(x_n, n)

# %% [markdown]
# **Linear sequence**
#      $x_n = 1 + n$

# %%
n = np.arange(1, 21)
x_n = np.column_stack((1 + n, 0*n))
plot_xn(x_n, n)
